# %% [markdown]
# <a href="https://colab.research.google.com/github/ArchitTiwary007/Striver_SHEET/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/knn_dataset - knn_dataset.csv")
print("Shape:",df.shape)
print(df.head())
# Out:
# Shape: (15, 6)
#    ID  Feature1  Feature2  Feature3  Feature4 Class
# 0   1       5.1       3.5       1.4       0.2     A
# 1   2       4.9       3.0       1.4       0.2     A
# 2   3       5.8       2.7       5.1       1.9     C
# 3   4       6.0       2.2       4.0       1.0     B
# 4   5       5.5       2.3       4.0       1.3     B

# %% [markdown]
# Training Dataset

# %%
from sklearn.model_selection import train_test_split
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
from sklearn.preprocessing import StandardScaler
Scalar=StandardScaler()
x_train=Scalar.fit_transform(x_train)
x_test=Scalar.transform(x_test)
x_train
y_train
# Out:
# 13    A
# 5     C
# 8     C
# 2     C
# 1     A
# 14    B
# 4     B
# 7     A
# 10    B
# 12    B
# 3     B
# 6     B
# Name: Class, dtype: object

# %% [markdown]
# Implement KNN using sklearn

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
saccuracy=accuracy_score(y_test,y_pred)
print(saccuracy)
print(y_test)
# Out:
# 1.0
# 9     A
# 11    C
# 0     A
# Name: Class, dtype: object

# %%
from collections import Counter
import numpy as np
def eucledian_distance(x1,x2):
  return np.sqrt(np.sum((x1-x2)**2))
def predict__knn(x_test,x_train,y_train,k=3):
  predictions=[]
  for test_point in x_test:
    distances=[]
    for i in range(len(x_train)):
      dist=eucledian_distance(test_point,x_train(i))
      distances.append((dist,y_train,iloc[i]))
    distances.sort(key=lambda x : x[0])
    neighbors=distances[:k]
    labels=[label, for_,label in neighbors]
    most_common=Counter(labels).most_common(1)[0][0]
    predictions.append(most_common)
  return np.array(predictions)
  y_pred=predict_knn(x_test,x_train,y_train,k=3)
eaccuracy=accuracy_score(y_test,y_pred)
print("Accuracy",eaccuracy)
print(y_test)
# Out:
# Accuracy 1.0
# 9     A
# 11    C
# 0     A
# Name: Class, dtype: object

# %% [markdown]
# Manhattan Distance

# %%
from collections import Counter
import numpy as np
from sklearn.metrics import accuracy_score

def manhattan(x1, x2):
    return np.sum(np.abs(x1 - x2))

def predict_knn(x_train, x_test, y_train, k=3):
    predictions = []

    for test_point in x_test:
        distances = []

        for i in range(len(x_train)):
            dist = manhattan(test_point, x_train[i])
            distances.append((dist, y_train.iloc[i]))

        distances.sort(key=lambda x: x[0])

        neighbors = distances[:k]

        labels = [label for _, label in neighbors]

        most_common = Counter(labels).most_common(1)[0][0]

        predictions.append(most_common)

    return np.array(predictions)

y_pred = predict_knn(x_train, x_test, y_train, k=3)

maccuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", maccuracy)
print(y_pred)
# Out:
# Accuracy: 1.0
# ['A' 'C' 'A']

# %%
print("Sklearn(Eucledian):",saccuracy)
print("Manual(Eucledian):",eaccuracy)
print("Manual(Manhattan):",maccuracy)
# Out:
# Sklearn(Eucledian): 1.0
# Manual(Eucledian): 1.0
# Manual(Manhattan): 1.0
